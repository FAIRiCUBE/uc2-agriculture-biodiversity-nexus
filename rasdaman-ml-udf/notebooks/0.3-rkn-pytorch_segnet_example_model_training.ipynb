# %% [markdown]
# # PyTorch EO Semantic Segmentation Example
# ## Step 3: Training of the SegNet model
# *Rob Knapen, Wageningen Environmental Research*
# <br>
#
# This notebook provides an EO deep learning example for semantic segmentation, using a SegNet network. It was trained on Sentinel-2 data (as features) and crop types from the Dutch LPIS (2018) for a small study area in The Netherlands.
#
# Originally this notebook has been used to train the model on Google Colab (using a GPU). It is provided here as reference material, with the original output included. Preparing adequate input data for this type of deep learning model is a separate (and time-consuming) step, which is not described in this notebook.

# %%
# connect to Google Drive for access to the training data
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Note: To see a folder that is shared with you, you need to create
#   a shortcut for it on your Google Drive before it you can access
#   it here in CoLab.

# expect a data / inputs folder with hdf5 files containing archived
# input data created from train and test images.
# !ls '/content/drive/MyDrive/AI_WENR/data/inputs'
# Out:
# crops_training_data_s2_10m_2018seasons_224x224x28_155cat.hdf5
# crops_training_data_s2_10m_2018seasons_224x224x28_76cat.hdf5

# %%
# setup paths to the data (on connected Google Drive)
import os
import h5py

# construct the paths to the training data
content_root_folder = os.path.join('/content', 'drive', 'MyDrive', 'AI_WENR', 'data')

# HDF5 file with input data
hdf5_file = os.path.join(content_root_folder, 'inputs', 'crops_training_data_s2_10m_2018seasons_224x224x28_76cat.hdf5')

# TODO should move encodings info into the HDF5 archive file

# file with information about the encoding used for the labels
codes_folder = os.path.join(content_root_folder, 'codes')
codes_file = os.path.join(codes_folder, 'cell_value_to_crop_info_76_classes.csv')

# %%
# setup paths to the data (on local drive)
import os
import h5py

content_root_folder = os.path.join('..', 'data')
hdf5_file = os.path.join(content_root_folder, 'archives', 'crops_training_data_s2_10m_2018seasons_224x224x28_76cat.hdf5')

codes_folder = os.path.join(content_root_folder, 'raw')
codes_file = os.path.join(codes_folder, 'cell_value_to_crop_info_76_classes.csv')

# %%
# open the input file
data_file = h5py.File(hdf5_file, "r")

print("(Attribute, Value:)");
for item in data_file.attrs.items():
    print(item);

train_obs = data_file['train_observation'][:]
train_gt = data_file['train_groundtruth'][:]
test_obs = data_file['test_observation'][:]
test_gt = data_file['test_groundtruth'][:]
n_train = train_obs.shape[0]
n_test = test_obs.shape[0]

print("%d tiles for training, %d tiles for testing" % (n_train, n_test))
# Out:
# (Attribute, Value:)
# ('description', 'This data set is intended for training deep learning models for crop classification.')
# ('ground_truth', 'Encoded crop types for fields according to the RVO registration in 2018.')
# ('ground_truth_shape', '1,224,224; 76 classes, int16')
# ('observations', '4 Bands (blue, green, red, nir) of 7 seasonal Sentinel 2 images, from 2018.')
# ('observations_shape', '28,224,224; scaled [0-1], float32')
# ('spatial_extent', 'Sample area around the Noordoost polder in The Netherlands.')
# ('spatial_resolution', '10x10m grid cells')
# ('title', 'Crop classification training data set')
# 151 tiles for training, 43 tiles for testing

# %%
# local install required libraries (only on Google Colab)
# !pip install torchnet mock
# Out:
# Requirement already satisfied: torchnet in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (0.0.4)
# Requirement already satisfied: mock in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (5.0.1)
# Requirement already satisfied: torch in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from torchnet) (1.12.1)
# Requirement already satisfied: six in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from torchnet) (1.16.0)
# Requirement already satisfied: visdom in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from torchnet) (0.1.8.9)
# Requirement already satisfied: typing-extensions in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from torch->torchnet) (4.4.0)
# Requirement already satisfied: pyzmq in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (24.0.1)
# Requirement already satisfied: websocket-client in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (1.4.2)
# Requirement already satisfied: numpy>=1.8 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (1.23.5)
# Requirement already satisfied: requests in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (2.28.1)
# Requirement already satisfied: torchfile in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (0.1.0)
# Requirement already satisfied: scipy in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (1.9.3)
# Requirement already satisfied: tornado in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (6.1)
# Requirement already satisfied: pillow in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (9.2.0)
# Requirement already satisfied: jsonpatch in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from visdom->torchnet) (1.32)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from jsonpatch->visdom->torchnet) (2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from requests->visdom->torchnet) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from requests->visdom->torchnet) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from requests->visdom->torchnet) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/robknapen/opt/mambaforge/envs/fairicube/lib/python3.10/site-packages (from requests->visdom->torchnet) (2.1.1)

# %%
# check if we can import all needed of PyTorch
import torch
import torchnet as tnt
import torch.nn.functional as nnf
import torch.nn as nn
import torch.optim as optim

from tqdm.notebook import tqdm

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    gpu_available = 1
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Reserved:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
else:
    gpu_available = 0
# Out:
# Using device: cpu

# %%
# some other standard imports that are needed
import random
import functools
from functools import partial
import mock
import math
import numpy as np
import pandas as pd

from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix

from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# read encodings data
encodings_df = pd.read_csv(codes_file)
class_names = encodings_df.sort_values(['cell_value'])['crop_name']
print(class_names.shape)

# create a colormap for viewing the ground truth images
# use one of these: viridis, plasma, inferno, magma
# or gist_earth, gist_rainbow, gist_ncar
max_cell_value = encodings_df['cell_value'].max()
print(max_cell_value)

class_cm = cm.get_cmap('gist_ncar', max_cell_value)
# Out:
# (76,)
# 76

# %%
# define a data loader

def augment(obs, gt):
  """the augmentation functions
  """
  # sigma, clip= 0.01, 0.03 
  # use np.clip to clip and np.random.randn to generate gaussian noise
  # obs = obs + np.clip(#TODO).astype(np.float32)
  # noise = np.random.normal(loc=0, scale=1, size=obs.shape)
  # obs = obs + np.clip(noise, 0.01, 0.03).astype(np.float32)

  #random rotation 0 90 180 270 degree
  n_turn = np.random.randint(0,3)
  for turn in range(n_turn):
    obs = np.rot90(obs, axes=(1,2)).copy()
    gt = np.rot90(gt, axes=(0,1)).copy()

  return obs, gt


def tile_loader(tile_index, train = True, cuda = gpu_available):
  """
  load a tile and returns the observation and associated ground truth
  INPUT:
  tile_index = int, index of the tile
  train = bool, train = True iff in the train set
  cuda = int, cuda = 1 if using GPU, 0 for CPU only
  OUTPUT
  obs, float array containing the observation
  gt, uint8 array, containing the pixels semantic labels  
  """
  if train:
    obs = train_obs[tile_index,:,:,:].transpose(2,0,1) #put channels first
    gt = train_gt[tile_index,:,:]
  else:
    obs = test_obs[tile_index,:,:,:].transpose(2,0,1)
    gt = test_gt[tile_index,:,:]
    
  if train: #augmentation - for training only
    obs, gt = augment(obs, gt)   
  
  # create torch wrapper
  obs = torch.from_numpy(obs)
  gt = torch.from_numpy(gt)
  
  if cuda: #put on GPU memory
    obs = obs.cuda()
   
  return obs, gt.long() #ground truth must have long int type

# create train and test dataset with ListDataset
test_set  = tnt.dataset.ListDataset(list(range(n_test)),functools.partial(tile_loader, train=False))
train_set = tnt.dataset.ListDataset(list(range(n_train)),functools.partial(tile_loader, train=True))

# %%
# functions used for visualization

def view_rgb(tile, ax = None):
  """ show the rgb values of the tile in figure ax"""
  if ax == None:
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1, aspect='equal')
  tile_corrected = np.minimum(np.maximum(tile[:3,:,], 0), 1) # normalization
  tile_corrected *= 5.0
  ax.imshow(tile_corrected.transpose(0,2).transpose(0,1)) # put channels back as dim 3
  plt.axis('off')
  
def view_infrared(tile, ax = None):
  """ show the infrared tile in figure ax"""
  if ax == None:
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1, aspect='equal')
  tile_corrected = np.minimum(np.maximum(tile[3,:,:], 0), 1) # normalization
  ax.imshow(tile_corrected, cmap='hot')
  plt.axis('off')

def view_labels(label, ax = None, mask = None,):
  """ show the ground truth with a colorcode corresponding to labels"""
  if ax == None:
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1, aspect='equal')
  if mask is not None:
    label[mask] = 0
  # n_pixel = label.shape[1]
  ax.imshow(label, cmap=class_cm)
  plt.axis('off')
  
def view_error(pred, gt, ax = None):
  """ show the error between pred and gt with colorcode:
 green when 'gt'='pred', red when 'gt'!='pred' and black
 when unnannotated (gt = 0)"""
  if ax == None:
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(1, 1, 1, aspect='equal')
  n_pixel = gt.shape[1]
  colors = np.zeros((n_pixel,n_pixel,3))
  colors[np.where(pred == gt.squeeze())] = [0, 1, 0] # correct prediction
  colors[np.where(pred != gt.squeeze())] = [1, 0, 0] # error
  colors[np.where(gt.squeeze() == 0)] = [0, 0, 0]   # unannotated 
  ax.imshow(colors)
  plt.axis('off')
  
def viewer(n_shown = 3, category = 'cig', train = True, model = None, use_mask = False):
  """ plot 'n_shown' random tiles train/test set with the following visuals:
  if 'c' in category : rgb color
  if 'i' in category : infrared
  if 'g' in category : ground truth
  if 'p' in category : prediction
  if 'e' in category : error
  Note that for 'p' or 'e' you need to add a trained model as input
  
  """
  n_category = len(category) # number of types of image to show
  fig = plt.figure(figsize=(n_category * 5, n_shown * 5)) # adapted dimension
  
  subplot_index = 1 # keep track of current subplot
  
  # chose random tiles
  tile_indices = np.random.choice(n_train, n_shown) if train \
  else np.random.choice(n_test, n_shown)
  
  for tile_index in tile_indices:
    
    tile, gt = tile_loader(tile_index, train = train, cuda=0)
    
    if 'c' in category:
      ax = fig.add_subplot(n_shown, n_category, subplot_index, aspect='equal')
      if subplot_index <= n_category : 
        ax.set(title='RGB')
      view_rgb(tile, ax = ax)
      subplot_index += 1
    if 'i' in category:  
      ax = fig.add_subplot(n_shown, n_category, subplot_index, aspect='equal')
      if subplot_index <= n_category : 
        ax.set(title='Infrared')
      view_infrared(tile, ax = ax)
      subplot_index += 1
    if 'g' in category:  
      ax = fig.add_subplot(n_shown, n_category, subplot_index, aspect='equal')
      if subplot_index <= n_category : 
        ax.set(title='Ground Truth')
      view_labels(gt, ax = ax)
      subplot_index += 1
    if 'p' in category:  
      ax = fig.add_subplot(n_shown, n_category, subplot_index, aspect='equal')
      if subplot_index <= n_category : 
        ax.set(title='Prediction')
      if gpu_available:
        pred = model(tile[None,:,:,:].cuda()).cpu().argmax(1).squeeze()
      else:
        pred = model(tile[None,:,:,:]).argmax(1).squeeze()
      if use_mask:
        pred[gt==0] = 0
      view_labels(pred, ax = ax)
      subplot_index += 1  
    if 'e' in category: 
      ax = fig.add_subplot(n_shown, n_category, subplot_index, aspect='equal')
      if subplot_index <= n_category : 
        ax.set(title='Error')
      if gpu_available:
        pred = model(tile[None,:,:,:].cuda()).cpu().argmax(1).squeeze()
      else:
        pred = model(tile[None,:,:,:]).argmax(1).squeeze()
      view_error(pred, gt, ax = ax)
      subplot_index += 1
  plt.show()

# %%
# show a few tiles (c=rgb, i=infrared, g=ground_truth)
viewer(3, 'cig')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class ConfusionMatrix:
  def __init__(self, n_class, class_names):
    self.CM = np.zeros((n_class, n_class))
    self.n_class = n_class
    self.class_names = class_names
  
  def clear(self):
    self.CM = np.zeros((self.n_class, self.n_class))
    
  def add_batch(self, gt, pred):
    self.CM += confusion_matrix(gt, pred, labels = list(range(self.n_class)))
    
  def overall_accuracy(self): # percentage of correct classification
    return (np.trace(self.CM) / np.sum(self.CM))*100

  def class_IoU(self, show = 1):
    ious = np.full(self.n_class, 0.)
    for i_class in range(self.n_class):
      sum = 0.0
      for j in range(self.n_class):
        if (j != i_class):
          sum += self.CM[i_class,j] + self.CM[j,i_class]
      ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
    
    if show:
      print('  |  '.join('{} : {:3.2f}%'.format(name, 100*iou) for name, iou in zip(self.class_names,ious)))
    
    # do not count classes that are not present in the dataset in the mean IoU
    return 100*np.nansum(ious) / (np.logical_not(np.isnan(ious))).sum()

# %%
# define a SegNet architecture

class SegNet(nn.Module):
  """
  EncoderDecoder network for semantic segmentation
  """
  
  def __init__(self, n_channels, encoder_conv_width, decoder_conv_width, n_class, cuda = 0):
    """
    initialization function
    n_channels, int, number of input channel
    encoder_conv_width, int list, size of the feature maps depth for the encoder after each conv
    decoder_conv_width, int list, size of the feature maps depth for the decoder after each conv
    n_class = int,  the number of classes
    """
    super(SegNet, self).__init__() # necessary for all classes extending the module class
    
    assert((encoder_conv_width[3] == encoder_conv_width[5]) \
     and (encoder_conv_width[1] == decoder_conv_width[1]))
    
    self.maxpool=nn.MaxPool2d(2,2,return_indices=True) # maxpooling layer
    self.unpool=nn.MaxUnpool2d(2,2) # unpooling layer
    
    # encoder
    self.c1 = nn.Sequential(
        nn.Conv2d(n_channels, encoder_conv_width[0], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[0]),
        nn.ReLU(True))
    self.c2 = nn.Sequential(
        nn.Conv2d(encoder_conv_width[0], encoder_conv_width[1], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[1]),
        nn.ReLU(True))
    self.c3 = nn.Sequential(
        nn.Conv2d(encoder_conv_width[1], encoder_conv_width[2], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[2]),
        nn.ReLU(True))
    self.c4 = nn.Sequential(
        nn.Conv2d(encoder_conv_width[2], encoder_conv_width[3], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[3]),
        nn.ReLU(True))
    self.c5 = nn.Sequential(
        nn.Conv2d(encoder_conv_width[3], encoder_conv_width[4], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[4]),
        nn.ReLU(True))
    self.c6 = nn.Sequential(
        nn.Conv2d(encoder_conv_width[4], encoder_conv_width[5], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(encoder_conv_width[5]),
        nn.ReLU(True))

    # decoder
    self.c7=nn.Sequential(
        nn.Conv2d(encoder_conv_width[5] + encoder_conv_width[3], decoder_conv_width[0], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(decoder_conv_width[0]),
        nn.ReLU(True))
    self.c8=nn.Sequential(
        nn.Conv2d(decoder_conv_width[0], decoder_conv_width[1], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(decoder_conv_width[1]),
        nn.ReLU(True))       
    self.c9=nn.Sequential(
        nn.Conv2d(encoder_conv_width[1] + decoder_conv_width[1], decoder_conv_width[2], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(decoder_conv_width[2]),
        nn.ReLU(True))
    self.c10=nn.Sequential(
        nn.Conv2d(decoder_conv_width[2], decoder_conv_width[3], 3, padding=1, padding_mode='reflect'),
        nn.BatchNorm2d(decoder_conv_width[3]),
        nn.ReLU(True)) # for regularisation could add dropout here, nn.Dropout()
    
    # final classifying layer
    self.classifier=nn.Conv2d(decoder_conv_width[3], n_class, 3, padding=1, padding_mode='reflect')

    # weight initialization
    self.c1[0].apply(self.init_weights)
    self.c2[0].apply(self.init_weights)
    self.c3[0].apply(self.init_weights)
    self.c4[0].apply(self.init_weights)
    self.c5[0].apply(self.init_weights)
    self.c6[0].apply(self.init_weights)
    self.c7[0].apply(self.init_weights)
    self.c8[0].apply(self.init_weights)
    self.c9[0].apply(self.init_weights)
    self.c10[0].apply(self.init_weights)
    self.classifier.apply(self.init_weights)
    
    if cuda: # put the model on the GPU memory
      self.cuda()
    
  def init_weights(self,layer): # gaussian init for the conv layers
    nn.init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
    
  def forward(self,input):
    """
    the function called to run inference
    """  
    # encoder
    #level 1
    x1 = self.c2(self.c1(input))
    x2, indices_a_b = self.maxpool(x1)
    #level 2
    x3= self.c4(self.c3(x2))
    x4, indices_b_c =self.maxpool(x3)
    #level 3
    x5 = self.c6(self.c5(x4))
    # decoder
    #level 2       
    y4 = self.unpool(x5, indices_b_c, x2.size())
    y3 = self.c8(self.c7(torch.cat((y4,x3), 1)))
    # level 1       
    y2 = self.unpool(y3, indices_a_b, x1.size())
    y1 = self.c10(self.c9(torch.cat((y2,x1), 1)))
    # output         
    out = self.classifier(y1)
    return out

# %%
# define model training and evaluation functions

def train(model, optimizer, scheduler, args):
  """train for one epoch"""
  model.train() #switch the model in training mode
  
  # the loader function will take care of the batching
  loader = torch.utils.data.DataLoader(train_set, \
         batch_size=args.batch_size, shuffle=True, drop_last=True)
  
  # tqdm will provide some nice progress bars
  loader = tqdm(loader, ncols=500)
  
  # will keep track of the loss
  loss_meter = tnt.meter.AverageValueMeter()
  cm = ConfusionMatrix(args.n_class, class_names = class_names)

  for index, (tiles, gt) in enumerate(loader):
    
    optimizer.zero_grad() # put gradient to zero
    
    pred = model(tiles) # compute the prediction

    loss = nn.functional.cross_entropy(pred.cpu(), 
                                       gt, 
                                       ignore_index=args.ignore_index)
                                       # weight=args.weights)

    loss.backward() # compute gradients

    for p in model.parameters(): # we clip the gradient at norm 1
      p.grad.data.clamp_(-1, 1) # this helps learning faster
    
    optimizer.step() # one SGD step
    scheduler.step()
    
    loss_meter.add(loss.item())
    labeled = np.where(gt.view(-1) != 0)[0] # select gt with a label
    # need to put the prediction back on the cpu and convert to numpy
    cm.add_batch(gt.view(-1)[labeled], pred.argmax(1).view(-1)[labeled].cpu().detach().numpy())
    
  return cm, loss_meter.value()[0]


def eval(model, args):
  """eval on test/validation set"""
  
  model.eval() # switch in eval mode
  
  loader = torch.utils.data.DataLoader(test_set, batch_size=1, shuffle=False, drop_last=False)
  
  loader = tqdm(loader, ncols=500)
  
  loss_meter = tnt.meter.AverageValueMeter()
  cm = ConfusionMatrix(args.n_class, class_names = class_names)

  with torch.no_grad():
    for index, (tiles, gt) in enumerate(loader):
      pred = model(tiles) # compute the prediction
      loss = nn.functional.cross_entropy(pred.cpu(), 
                                         gt, 
                                         ignore_index=args.ignore_index)
                                         # weight=args.weights)
      loss_meter.add(loss.item())
      labeled = np.where(gt.view(-1) != 0)[0] # select gt with a label
      # need to put the prediction back on the cpu and convert to numpy
      cm.add_batch(
          gt.view(-1)[labeled], 
          pred.argmax(1).view(-1)[labeled].cpu().detach().numpy())
      
  return cm, loss_meter.value()[0]


def train_full(args):
  """The full training loop"""
  # initialize the model
  
  model = SegNet(args.n_channel, args.conv_width, args.dconv_width, args.n_class, cuda=args.cuda)

  print('Total number of parameters: {}'.format(sum([p.numel() for p in model.parameters()])))
  
  # define the optimizer
  optimizer = optim.Adam(model.parameters(), lr=args.lr)
  scheduler = optim.lr_scheduler.MultiStepLR(optimizer=optimizer, milestones=[100,150], gamma=0.7)
  
  TESTCOLOR = '\033[104m'
  TRAINCOLOR = '\033[100m'
  NORMALCOLOR = '\033[0m'
  
  for i_epoch in range(args.n_epoch):
    # train one epoch
    cm_train, loss_train = train(model, optimizer, scheduler, args)
    print(TRAINCOLOR)
    print('Epoch %3d -> Train Overall Accuracy: %3.2f%% Train mIoU : %3.2f%% Train Loss: %1.4f' % (i_epoch, cm_train.overall_accuracy(), cm_train.class_IoU(), loss_train) + NORMALCOLOR)

    if (i_epoch == args.n_epoch - 1) or (args.n_epoch_test != 0 and i_epoch % args.n_epoch_test == 0 and i_epoch > 0):
      # periodic testing
      cm_test, loss_test = eval(model, args)
      print(TESTCOLOR)
      print('Test Overall Accuracy: %3.2f%% Test mIoU : %3.2f%%  Test Loss: %1.4f' % (cm_test.overall_accuracy(), cm_test.class_IoU(), loss_test) + NORMALCOLOR)
      viewer(n_shown = 1, train = False, model = model, category = 'cigpe', use_mask = False)
  return model

# %%
# set arguments (includes class loss weights) and train the model
args = mock.Mock()
args.n_epoch_test = int(5)
args.cuda = gpu_available

args.n_class      = 77
args.n_channel    = 28
args.conv_width   = [64,64,128,128,256,128]
args.dconv_width  = [128,64,128,64]

args.ignore_index = 0 # index of the nodata value

weights = torch.ones(76)
weights[1] = 2.0 # grasland, blijvend
weights[2] = 1.5 # grasland, tijdelijk

args.weights      = weights

args.n_epoch    = 10
args.batch_size = 4
args.lr         = 5e-4 # TODO improve lr schedule?

trained_model = train_full(args)
# Out:
# Total number of parameters: 1501709
#   0%|                                                                                                         …
# Grasland, blijvend : 0.00%  |  Grasland, tijdelijk : 50.72%  |  Gerst, zomer- : 8.85%  |  Mais, snij- : 2.08%  |  Witte kool, productie : 37.62%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 26.97%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 46.57%  |  Bieten, voeder- : 47.44%  |  Bos, blijvend, met herplantplicht : 0.03%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.12%  |  Bieten, suiker- : 0.79%  |  Bos zonder herplantplicht : 44.19%  |  Triticale : 0.05%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 0.36%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 50.76%  |  Aardappelen, consumptie : 0.23%  |  Bloemkool, zomer, productie : 10.70%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.36%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 0.14%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 28.24%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 0.05%  |  Rogge (geen snijrogge) : 0.08%  |  Aardappelen, zetmeel : 0.09%  |  Kroten/rode bieten, productie : 0.14%  |  Mais, korrel- : 0.07%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.09%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 0.00%  |  Uien, poot- en plant- (incl. sjalotten) : 0.00%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 0.03%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.34%  |  Pastinaak, productie : 0.00%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : 0.00%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.01%  |  Graszaad : 0.00%  |  Hennep, vezel- : 0.02%  |  Tagetes patula (Afrikaantje) : 0.19%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : 0.00%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 0.02%  |  Krokus, bloembollen en - knollen : 0.21%  |  Spinazie, productie : 0.02%  |  Sojabonen : 0.00%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   0 -> Train Overall Accuracy: 50.50% Train mIoU : 4.64% Train Loss: 2.0816
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 63.41%  |  Gerst, zomer- : 3.35%  |  Mais, snij- : 14.06%  |  Witte kool, productie : 57.60%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 49.01%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 68.17%  |  Bieten, voeder- : 57.01%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 61.23%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 2.54%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 62.99%  |  Aardappelen, consumptie : 0.00%  |  Bloemkool, zomer, productie : 18.58%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.00%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 1.04%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 61.58%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 0.00%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 0.00%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 0.00%  |  Uien, poot- en plant- (incl. sjalotten) : 0.00%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 0.43%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 0.01%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 0.00%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 1.57%  |  Krokus, bloembollen en - knollen : 0.00%  |  Spinazie, productie : 0.00%  |  Sojabonen : 0.00%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   1 -> Train Overall Accuracy: 65.33% Train mIoU : 7.06% Train Loss: 1.2940
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 65.72%  |  Gerst, zomer- : 9.35%  |  Mais, snij- : 14.62%  |  Witte kool, productie : 67.17%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 49.70%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 69.11%  |  Bieten, voeder- : 59.55%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 68.40%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 7.07%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 67.94%  |  Aardappelen, consumptie : 0.00%  |  Bloemkool, zomer, productie : 23.86%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.00%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 1.71%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 68.87%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 0.00%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 0.11%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 0.51%  |  Uien, poot- en plant- (incl. sjalotten) : 0.08%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 12.67%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 3.16%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 2.61%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 23.03%  |  Krokus, bloembollen en - knollen : 0.00%  |  Spinazie, productie : 0.00%  |  Sojabonen : 0.00%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   2 -> Train Overall Accuracy: 68.00% Train mIoU : 8.31% Train Loss: 1.1399
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 63.37%  |  Gerst, zomer- : 13.21%  |  Mais, snij- : 18.50%  |  Witte kool, productie : 67.16%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 51.78%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 72.57%  |  Bieten, voeder- : 59.99%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 74.25%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 7.58%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 65.65%  |  Aardappelen, consumptie : 0.00%  |  Bloemkool, zomer, productie : 23.30%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.00%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 4.42%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 65.74%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 0.90%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 11.07%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 5.23%  |  Uien, poot- en plant- (incl. sjalotten) : 2.14%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 10.81%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 0.22%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 5.19%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 31.47%  |  Krokus, bloembollen en - knollen : 0.00%  |  Spinazie, productie : 0.00%  |  Sojabonen : 0.00%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   3 -> Train Overall Accuracy: 67.77% Train mIoU : 8.85% Train Loss: 1.1299
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 65.36%  |  Gerst, zomer- : 14.74%  |  Mais, snij- : 18.11%  |  Witte kool, productie : 71.10%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 52.51%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 74.09%  |  Bieten, voeder- : 61.45%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 75.48%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 10.84%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 69.06%  |  Aardappelen, consumptie : 0.06%  |  Bloemkool, zomer, productie : 28.84%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.04%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 4.03%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 70.83%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 0.31%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 10.90%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 3.42%  |  Uien, poot- en plant- (incl. sjalotten) : 5.69%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 14.21%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 0.72%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 13.99%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 37.34%  |  Krokus, bloembollen en - knollen : 0.03%  |  Spinazie, productie : 0.00%  |  Sojabonen : 0.04%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   4 -> Train Overall Accuracy: 69.61% Train mIoU : 9.50% Train Loss: 1.0200
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 67.05%  |  Gerst, zomer- : 18.56%  |  Mais, snij- : 23.13%  |  Witte kool, productie : 74.26%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 54.82%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 74.75%  |  Bieten, voeder- : 63.34%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 77.27%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 11.10%  |  Bos- en haagplanten, open grond, : 0.07%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 71.57%  |  Aardappelen, consumptie : 0.13%  |  Bloemkool, zomer, productie : 28.35%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.04%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 8.74%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 73.29%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 1.44%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 15.92%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 4.61%  |  Uien, poot- en plant- (incl. sjalotten) : 12.50%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 15.69%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 5.37%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 16.73%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 41.10%  |  Krokus, bloembollen en - knollen : 0.53%  |  Spinazie, productie : 0.00%  |  Sojabonen : 1.43%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   5 -> Train Overall Accuracy: 71.17% Train mIoU : 10.29% Train Loss: 0.9639
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 66.17%  |  Gerst, zomer- : 23.56%  |  Mais, snij- : 24.62%  |  Witte kool, productie : 71.29%  |  Winterpeen, productie : nan%  |  Buxus, open grond, : 60.88%  |  Uien, zaai- : nan%  |  Aardappelen, poot NAK : 78.10%  |  Bieten, voeder- : 64.12%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 76.87%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 21.36%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 73.16%  |  Aardappelen, consumptie : 0.10%  |  Bloemkool, zomer, productie : 24.52%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.05%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 22.16%  |  Tulp, bloembollen en -knollen : nan%  |  Gerst, winter- : 76.52%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 26.47%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 19.28%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : nan%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 0.00%  |  Uien, poot- en plant- (incl. sjalotten) : 17.14%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 17.31%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : nan%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 3.99%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 23.45%  |  Tagetes patula (Afrikaantje) : nan%  |  Witlofwortel, productie : nan%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : nan%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 28.99%  |  Krokus, bloembollen en - knollen : 0.00%  |  Spinazie, productie : nan%  |  Sojabonen : 0.00%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : nan%  |  Pompoen, zaden en opkweekmateriaal : nan%
# Test Overall Accuracy: 70.84% Test mIoU : 13.23%  Test Loss: 0.9885
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 67.14%  |  Gerst, zomer- : 21.97%  |  Mais, snij- : 21.27%  |  Witte kool, productie : 73.48%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 55.33%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 75.23%  |  Bieten, voeder- : 64.32%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.33%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 79.11%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 12.47%  |  Bos- en haagplanten, open grond, : 0.02%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 70.73%  |  Aardappelen, consumptie : 0.05%  |  Bloemkool, zomer, productie : 28.07%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.01%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 0.50%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 9.44%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 74.49%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 7.97%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 16.40%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 17.88%  |  Uien, poot- en plant- (incl. sjalotten) : 13.04%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 16.77%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 0.56%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 25.24%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 44.61%  |  Krokus, bloembollen en - knollen : 2.27%  |  Spinazie, productie : 0.00%  |  Sojabonen : 10.03%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   6 -> Train Overall Accuracy: 71.37% Train mIoU : 10.93% Train Loss: 0.9485
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 67.99%  |  Gerst, zomer- : 25.36%  |  Mais, snij- : 23.61%  |  Witte kool, productie : 76.48%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 57.12%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 76.46%  |  Bieten, voeder- : 64.25%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.02%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 79.84%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 15.61%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 73.60%  |  Aardappelen, consumptie : 0.23%  |  Bloemkool, zomer, productie : 30.04%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.01%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 4.87%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 6.71%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 77.36%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 25.24%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 22.86%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 14.62%  |  Uien, poot- en plant- (incl. sjalotten) : 16.75%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 17.74%  |  Pioenroos, overige bloemkwekerijgewassen : 0.00%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 11.21%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 35.92%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 47.85%  |  Krokus, bloembollen en - knollen : 0.87%  |  Spinazie, productie : 0.00%  |  Sojabonen : 10.30%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   7 -> Train Overall Accuracy: 72.50% Train mIoU : 11.93% Train Loss: 0.9044
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 67.83%  |  Gerst, zomer- : 24.85%  |  Mais, snij- : 20.46%  |  Witte kool, productie : 74.57%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 57.62%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 77.41%  |  Bieten, voeder- : 65.58%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 1.86%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 78.70%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 19.47%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 71.86%  |  Aardappelen, consumptie : 0.40%  |  Bloemkool, zomer, productie : 31.26%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.00%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 16.07%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 12.42%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 73.49%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 23.91%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 13.87%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 24.19%  |  Uien, poot- en plant- (incl. sjalotten) : 20.85%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 15.94%  |  Pioenroos, overige bloemkwekerijgewassen : 0.12%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 6.10%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 35.07%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 44.37%  |  Krokus, bloembollen en - knollen : 0.26%  |  Spinazie, productie : 0.00%  |  Sojabonen : 17.34%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   8 -> Train Overall Accuracy: 72.26% Train mIoU : 12.11% Train Loss: 0.9299
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 69.81%  |  Gerst, zomer- : 26.57%  |  Mais, snij- : 31.29%  |  Witte kool, productie : 75.03%  |  Winterpeen, productie : 0.00%  |  Buxus, open grond, : 57.72%  |  Uien, zaai- : 0.00%  |  Aardappelen, poot NAK : 77.92%  |  Bieten, voeder- : 66.07%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.73%  |  Bos zonder herplantplicht : 80.98%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 14.19%  |  Bos- en haagplanten, open grond, : 0.02%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 75.39%  |  Aardappelen, consumptie : 0.39%  |  Bloemkool, zomer, productie : 29.13%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.12%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 7.26%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 8.93%  |  Tulp, bloembollen en -knollen : 0.00%  |  Gerst, winter- : 79.18%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 28.22%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 23.69%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : 0.00%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 28.31%  |  Uien, poot- en plant- (incl. sjalotten) : 25.45%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 19.55%  |  Pioenroos, overige bloemkwekerijgewassen : 0.37%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : 0.00%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 12.25%  |  Mais, corncob mix : 0.02%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 49.95%  |  Tagetes patula (Afrikaantje) : 0.00%  |  Witlofwortel, productie : 0.00%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : 0.00%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 46.37%  |  Krokus, bloembollen en - knollen : 0.26%  |  Spinazie, productie : 0.00%  |  Sojabonen : 27.05%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : 0.00%  |  Pompoen, zaden en opkweekmateriaal : 0.00%
# Epoch   9 -> Train Overall Accuracy: 73.78% Train mIoU : 13.00% Train Loss: 0.8678
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)
#   0%|                                                                                                         …
# Grasland, blijvend : nan%  |  Grasland, tijdelijk : 68.59%  |  Gerst, zomer- : 30.11%  |  Mais, snij- : 17.79%  |  Witte kool, productie : 72.21%  |  Winterpeen, productie : nan%  |  Buxus, open grond, : 62.25%  |  Uien, zaai- : nan%  |  Aardappelen, poot NAK : 78.13%  |  Bieten, voeder- : 62.39%  |  Bos, blijvend, met herplantplicht : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie landbouw. : 0.00%  |  Haver : 0.00%  |  Bieten, suiker- : 0.00%  |  Bos zonder herplantplicht : 80.64%  |  Triticale : 0.00%  |  Tarwe, zomer- : 0.00%  |  Pompoen, productie : 23.13%  |  Bos- en haagplanten, open grond, : 0.00%  |  Vlas, vezel- : 0.00%  |  Tarwe, winter- : 0.00%  |  Grasland, natuurlijk. Hoofdfunctie natuur. : 69.42%  |  Aardappelen, consumptie : 0.78%  |  Bloemkool, zomer, productie : 27.13%  |  Overige groenbemesters, niet-vlinderbloemige- : 0.03%  |  Gladiool, bloembollen en - knollen : 0.00%  |  Grasland, natuurlijk. Areaal met een natuurbeheertype dat overwegend voor landbouwactiviteiten-GLB wordt gebruikt : 8.42%  |  Tijdelijk onbeteelde grond, anders dan voor publieke werken : 7.09%  |  Tulp, bloembollen en -knollen : nan%  |  Gerst, winter- : 79.83%  |  Peren. Aangeplant voorafgaande aan lopende seizoen. : 0.00%  |  Aardappelen, poot TBM : 58.18%  |  Rogge (geen snijrogge) : 0.00%  |  Aardappelen, zetmeel : 0.00%  |  Kroten/rode bieten, productie : 23.12%  |  Mais, korrel- : 0.00%  |  Sierconiferen, open grond, : 0.00%  |  Koolraap, productie : nan%  |  Bladrammenas : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit tijdelijk gras : 0.00%  |  Luzerne : 0.00%  |  Uien, zilver- : 14.04%  |  Uien, poot- en plant- (incl. sjalotten) : 9.26%  |  Appelen. Aangeplant voorafgaande aan lopende seizoen. : 11.57%  |  Pioenroos, overige bloemkwekerijgewassen : 0.02%  |  Koolzaad, winter (incl. boterzaad) : 0.00%  |  Knolselderij, productie : nan%  |  Natuurterreinen (incl. heide) : 0.00%  |  Pastinaak, productie : 31.58%  |  Mais, corncob mix : 0.00%  |  Tagetes erecta (Afrikaantje) : 0.00%  |  Klaver, rode : nan%  |  Aardappelen, bestrijdingsmaatregel AM : 0.00%  |  Waspeen, productie : 0.00%  |  Graszaad : 0.00%  |  Hennep, vezel- : 15.64%  |  Tagetes patula (Afrikaantje) : nan%  |  Witlofwortel, productie : nan%  |  Mais, suiker- : nan%  |  Rodekool, productie : 0.00%  |  Erwten, groene/gele (groen te oogsten) : nan%  |  Aardbeien open grond, vermeerdering : 0.00%  |  Engels raaigras : 0.00%  |  Stamsperziebonen (=stamslabonen), productie : 0.00%  |  Rand, grenzend aan bouwland, hoofdzakelijk bestaand uit een ander gewas dan gras. (EA: onbeheerd) : 0.00%  |  Hyacint, bloembollen en - knollen : 0.00%  |  Vruchtbomen, moerbomen, open grond, : 0.00%  |  Spinazie, zaden en opkweekmateriaal : 0.00%  |  Lelie, bloembollen en -knollen : 0.00%  |  Wortelpeterselie : 45.58%  |  Krokus, bloembollen en - knollen : 0.00%  |  Spinazie, productie : nan%  |  Sojabonen : 1.47%  |  Vruchtbomen, onderstammen, open grond, : 0.00%  |  Koolzaad, zomer (incl. boterzaad) : nan%  |  Pompoen, zaden en opkweekmateriaal : nan%
# Test Overall Accuracy: 72.30% Test mIoU : 14.49%  Test Loss: 0.9206
# /var/folders/71/dq62wtb15f9ckfvyn853m3d80000gn/T/ipykernel_89665/2121711847.py:23: RuntimeWarning: invalid value encountered in double_scalars
#   ious[i_class] = self.CM[i_class,i_class] / (self.CM[i_class,i_class] + sum)

# %%
# TODO fine-tune the model training, e.g. improve lr schedule, more data augmentation

# %%
trained_model
# Out:
# SegNet(
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (unpool): MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
#   (c1): Sequential(
#     (0): Conv2d(28, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c6): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c7): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c8): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c9): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (c10): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (classifier): Conv2d(64, 77, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
# )

# %%
# save trained model for inference
torch.save(trained_model.state_dict(), 'rvo_crops_segnet_224x224x28_77classes_10epochs_model_parameters.pt')
torch.save(trained_model, 'rvo_crops_segnet_224x224x28_77classes_10epochs_model_full.pt')
